# %% [markdown]
# # 카메라 스티커 앱 만들기
# 준비한 사진에 고양이 수염을 씌워주는 프로그램이다.

# %% [markdown]
# 작업 디렉토리 구조를 세팅

# %%
mkdir -p ~/aiffel/camera_sticker/models
mkdir -p ~/aiffel/camera_sticker/images
# Out:
#   File "<ipython-input-4-d313bec60dca>", line 1
#     mkdir -p ~/aiffel/camera_sticker/models
#              ^
# SyntaxError: invalid syntax

# %% [raw]
# 고양이 수염 이미지 다운받기 & 이미지 폴더로 이동

# %%
wget https://www.flaticon.com/free-icon/cat-whiskers_24674?term=cat%20nose&page=1&position=1
mv cat-whiskers.png ~/aiffel/camera_sticker/images
# Out:
#   File "<ipython-input-5-468de444eea5>", line 1
#     wget https://www.flaticon.com/free-icon/cat-whiskers_24674?term=cat%20nose&page=1&position=1
#              ^
# SyntaxError: invalid syntax

# %%
준비한 사진을 images 폴더에 파일명 image.jpg로 넣기. 
(파일 경로: ~/aiffel/camera_sticker/images)
# Out:
#   File "<ipython-input-6-ae0028a224e5>", line 1
#     준비한 사진을 images 폴더에 파일명 image.jpg로 넣기.
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# 이미지 처리 관련 패키지. (설치가 안되어 있다면 설치)
# $ pip install opencv-python
# $ pip install cmake
# $ pip install dlib

# %% [markdown]
# 이미지 처리를 위해 opencv 와 노트북에 이미지를 출력하기 위한 matplotlib를 읽어온다.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
print("읽어오기 완료")
# Out:
# 읽어오기 완료

# %%
준비한 이미지를 읽는다.
# Out:
#   File "<ipython-input-8-73acfd2c83d7>", line 1
#     준비한 이미지를 읽는다.
#            ^
# SyntaxError: invalid syntax

# %%
import os
my_image_path = os.getenv('HOME')+'/aiffel/camera_sticker/images/image.jpg'
img_bgr = cv2.imread(my_image_path)    #- OpenCV로 이미지를 읽어서
img_bgr = cv2.resize(img_bgr, (500, 640))    # 640x360의 크기로 Resize
img_show = img_bgr.copy()      #- 출력용 이미지 별도 보관
plt.imshow(img_bgr)
plt.show()
